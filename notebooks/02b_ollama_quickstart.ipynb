# %%
import ollama
r = ollama.chat (
    model="llama3.1:8b",
    messages=[{"role": "user", "content": "Explain RAG in the context of AI one paragraph."}]
)
print(r["message"]["content"])
# Out:
# In the context of Artificial Intelligence (AI), RAG stands for "Reasoning And Generation" or more specifically, "Ranker and Generator". It is a technique used to generate text that matches a given input prompt. A RAG model consists of two main components: a Ranker and a Generator. The Ranker component takes the input prompt as a query and retrieves a set of relevant documents or passages from a large corpus of text, ranking them based on relevance. The Generator then uses these retrieved passages to generate new text that is coherent and contextually accurate, often using techniques such as attention mechanisms and sequence-to-sequence models. By combining the strengths of both components, RAG models can produce high-quality text that is relevant, informative, and engaging.
